# %%
import matplotlib.pyplot as plt
import pandas as pd
#dataset = pd.read_csv('scores.csv')
#xMaths = dataset['Mathematics']
#yPhysics = dataset['Total']
#plt.plot(xMaths,yPhysics)
#plt.title("Graph of Maths and Physics")
#plt.xlabel("Maths")
#plt.ylabel("Physics")

empage=[20,21,25,25,25,26,28,29,27,30,32,34,36,36,37,38]
empsal=[20000,21000,23000,25000,28000,28000,40000,42000,48000,50000,51000,55000,70000,74000,76000,79000]
#plt.plot(empsal,empage) #Plots the Graph
plt.title("Age vs Salary of Employee")
plt.xlabel("Salary")
plt.ylabel("Age")
#plt.show()
plt.plot(empsal,empage, color='red', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='blue', markersize=10)
plt.grid(color="green",linewidth=1)

# %%
figure = plt.figure()
ax = figure.gca()
ax.scatter(empsal,empage)
ax.grid(color="green",linewidth=1)
